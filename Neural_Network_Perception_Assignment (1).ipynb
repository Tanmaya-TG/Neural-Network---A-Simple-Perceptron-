# %% [markdown]
# # Neural Network – A Simple Perceptron Assignment

# %% [markdown]
# ## Question 1: What is Deep Learning? How it evolved and differs from traditional ML
#
# **Answer:**
# Deep Learning is a subset of Machine Learning that uses artificial neural networks with many layers to learn complex patterns from large datasets. These models mimic the structure of the human brain.
#
# **Evolution:**
# 1. 1950s–1980s: Early neural network ideas like perceptron.
# 2. 1990s–2000s: Machine learning algorithms like SVM and decision trees became dominant.
# 3. 2010s–present: Deep learning emerged due to big data, GPUs, and improved algorithms.
#
# **Difference from Traditional ML:**
# - Traditional ML requires manual feature engineering.
# - Deep Learning automatically learns features.
# - Deep Learning works better with large and complex datasets.

# %% [markdown]
# ## Question 2: Architecture and functioning of a Perceptron
#
# **Answer:**
# A perceptron is the simplest type of artificial neural network used for binary classification.
#
# **Components:**
# - Input layer
# - Weights
# - Bias
# - Activation function
# - Output
#
# **Working:**
# 1. Inputs are multiplied with weights.
# 2. The weighted sum is calculated.
# 3. Bias is added.
# 4. Activation function determines the final output.
#
# **Limitations:**
# - Can only classify linearly separable data.
# - Cannot solve problems like XOR.

# %% [markdown]
# ## Question 3: Activation Functions
#
# **Purpose:** Activation functions introduce non-linearity into neural networks so they can learn complex patterns.
#
# | Function | Formula | Range | Advantages |
# |--------|--------|--------|--------|
# | Sigmoid | 1/(1+e^-x) | 0 to 1 | Good for probability output |
# | ReLU | max(0,x) | 0 to infinity | Fast and widely used |
# | Tanh | (e^x - e^-x)/(e^x + e^-x) | -1 to 1 | Centered around zero |

# %% [markdown]
# ## Question 4: Loss vs Cost Function
#
# **Loss Function:** measures error for a single training example.
#
# **Cost Function:** average loss over the entire dataset.
#
# Examples:
# - Mean Squared Error (MSE)
# - Binary Cross Entropy
# - Categorical Cross Entropy

# %% [markdown]
# ## Question 5: Optimizers in Neural Networks
#
# Optimizers adjust weights to minimize the loss function.
#
# | Optimizer | Description |
# |--------|--------|
# | Gradient Descent | Updates weights using gradient of loss |
# | Adam | Adaptive learning rate optimizer |
# | RMSprop | Maintains adaptive learning rate for each parameter |

# %% [markdown]
# ## Question 6: Single Layer Perceptron for AND Gate

# %%
import numpy as np

X = np.array([[0,0],[0,1],[1,0],[1,1]])
y = np.array([0,0,0,1])

weights = np.random.rand(2)
bias = np.random.rand(1)
lr = 0.1

def step(x):
    return 1 if x>=0 else 0

for epoch in range(10):
    for i in range(len(X)):
        linear = np.dot(X[i],weights)+bias
        pred = step(linear)
        error = y[i]-pred
        weights += lr*error*X[i]
        bias += lr*error

print('Weights:',weights)
print('Bias:',bias)
# Out:
# Weights: [0.20931704 0.11717414]
# Bias: [-0.23374431]

# %% [markdown]
# ## Question 7: Visualize Sigmoid, ReLU, and Tanh

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10,10,100)

sigmoid = 1/(1+np.exp(-x))
relu = np.maximum(0,x)
tanh = np.tanh(x)

plt.plot(x,sigmoid,label='Sigmoid')
plt.plot(x,relu,label='ReLU')
plt.plot(x,tanh,label='Tanh')
plt.legend()
plt.title('Activation Functions')
plt.show()

# %% [markdown]
# ## Question 8: Neural Network on MNIST using Keras

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Flatten

(x_train,y_train),(x_test,y_test)=mnist.load_data()

x_train=x_train/255.0
x_test=x_test/255.0

model=Sequential([
Flatten(input_shape=(28,28)),
Dense(128,activation='relu'),
Dense(10,activation='softmax')
])

model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

model.fit(x_train,y_train,epochs=5)
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8812 - loss: 0.4240
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9654 - loss: 0.1214
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9764 - loss: 0.0795
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9830 - loss: 0.0574
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9863 - loss: 0.0432

# %% [markdown]
# ## Question 9: Loss and Accuracy curves using Fashion MNIST

# %%
from tensorflow.keras.datasets import fashion_mnist

(x_train,y_train),(x_test,y_test)=fashion_mnist.load_data()

x_train=x_train/255.0
x_test=x_test/255.0

model=Sequential([
Flatten(input_shape=(28,28)),
Dense(128,activation='relu'),
Dense(10,activation='softmax')
])

model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

history=model.fit(x_train,y_train,epochs=5,validation_data=(x_test,y_test))

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Curve')
plt.show()
# Out:
# ...
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.7833 - loss: 0.6241 - val_accuracy: 0.8307 - val_loss: 0.4569
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8624 - loss: 0.3841 - val_accuracy: 0.8564 - val_loss: 0.3994
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8770 - loss: 0.3391 - val_accuracy: 0.8618 - val_loss: 0.3816
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8832 - loss: 0.3192 - val_accuracy: 0.8698 - val_loss: 0.3698
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8916 - loss: 0.2934 - val_accuracy: 0.8674 - val_loss: 0.3770

# %% [markdown]
# ## Question 10: Fraud Detection Deep Learning Workflow
#
# **Model Design:** Use a multilayer neural network with input layer, hidden layers (ReLU), and sigmoid output.
#
# **Activation Function:** ReLU for hidden layers, Sigmoid for binary classification.
#
# **Loss Function:** Binary Cross Entropy because fraud detection is a binary classification task.
#
# **Handling Imbalance:**
# - Use class weights
# - Oversampling or SMOTE
# - Evaluate using Precision, Recall, F1-score.
#
# **Optimizer:** Adam optimizer for faster convergence.
#
# **Prevent Overfitting:**
# - Dropout layers
# - Early stopping
# - Regularization
